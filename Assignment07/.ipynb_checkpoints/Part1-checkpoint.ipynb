# %% [markdown]
# # Assignment07 Part 1
# John Hadish

# %%
import pandas as pd

reviews = pd.read_csv("ign.csv")

# %%
reviews.head()
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
# ...

# %%
reviews.shape
# Out:
# (18625, 11)

# %%
reviews.iloc[0:8,:]
# Out:
#    Unnamed: 0 score_phrase                                              title  \
# 0           0      Amazing                            LittleBigPlanet PS Vita
# 1           1      Amazing  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2           2        Great                               Splice: Tree of Life
# 3           3        Great                                             NHL 13
# 4           4        Great                                             NHL 13
# 5           5         Good                          Total War Battles: Shogun
# 6           6        Awful                                Double Dragon: Neon
# 7           7      Amazing                                       Guild Wars 2
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# ...

# %%
reviews = reviews.iloc[:,1:]
reviews.head()
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
#
#         genre editors_choice  release_year  release_month  release_day
# 0  Platformer              Y          2012              9           12
# ...

# %%
reviews.loc[0:5,:]
# Out:
#                                                title  \
# 0                            LittleBigPlanet PS Vita
# 1  LittleBigPlanet PS Vita -- Marvel Super Hero E...
# 2                               Splice: Tree of Life
# 3                                             NHL 13
# 4                                             NHL 13
# 5                          Total War Battles: Shogun
#
#                                                  url          platform  score  \
# 0             /games/littlebigplanet-vita/vita-98907  PlayStation Vita    9.0
# 1  /games/littlebigplanet-ps-vita-marvel-super-he...  PlayStation Vita    9.0
# 2                          /games/splice/ipad-141070              iPad    8.5
# 3                      /games/nhl-13/xbox-360-128182          Xbox 360    8.5
# 4                           /games/nhl-13/ps3-128181     PlayStation 3    8.5
# 5         /games/total-war-battles-shogun/mac-142565         Macintosh    7.0
#
# ...

# %%
reviews.index
# Out:
# RangeIndex(start=0, stop=18625, step=1)

# %%
some_reviews = reviews.iloc[10:20,]
some_reviews.head()
# Out:
#                       title                                              url  \
# 10  Tekken Tag Tournament 2        /games/tekken-tag-tournament-2/ps3-124584
# 11  Tekken Tag Tournament 2   /games/tekken-tag-tournament-2/xbox-360-124581
# 12               Wild Blood                  /games/wild-blood/iphone-139363
# 13        Mark of the Ninja  /games/mark-of-the-ninja-135615/xbox-360-129276
# 14        Mark of the Ninja        /games/mark-of-the-ninja-135615/pc-143761
#
#          platform  score              genre editors_choice  release_year  \
# 10  PlayStation 3    7.5           Fighting              N          2012
# 11       Xbox 360    7.5           Fighting              N          2012
# 12         iPhone    7.0                NaN              N          2012
# 13       Xbox 360    9.0  Action, Adventure              Y          2012
# 14             PC    9.0  Action, Adventure              Y          2012
#
#     release_month  release_day
# 10              9           11
# ...

# %%
some_reviews.loc[7:,:]
# Out:
#                               title  \
# 10          Tekken Tag Tournament 2
# 11          Tekken Tag Tournament 2
# 12                       Wild Blood
# 13                Mark of the Ninja
# 14                Mark of the Ninja
# 15  Home: A Unique Horror Adventure
# 16  Home: A Unique Horror Adventure
# 17              Avengers Initiative
# 18             Way of the Samurai 4
# 19      JoJo's Bizarre Adventure HD
#
#                                                   url       platform  score  \
# 10          /games/tekken-tag-tournament-2/ps3-124584  PlayStation 3    7.5
# 11     /games/tekken-tag-tournament-2/xbox-360-124581       Xbox 360    7.5
# 12                    /games/wild-blood/iphone-139363         iPhone    7.0
# 13    /games/mark-of-the-ninja-135615/xbox-360-129276       Xbox 360    9.0
# 14          /games/mark-of-the-ninja-135615/pc-143761             PC    9.0
# 15  /games/home-a-unique-horror-adventure/mac-2001...      Macintosh    6.5
# ...

# %%
reviews.loc[:5,"score"]
# Out:
# 0    9.0
# 1    9.0
# 2    8.5
# 3    8.5
# 4    8.5
# 5    7.0
# Name: score, dtype: float64
